# %%
from __future__ import division
#
import os, sys
sys.path.append(os.getcwd()+'/..')
#
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#
from supports._setting import trips_dir
from supports._setting import DInAP_PInAP, DInAP_POutAP
from supports.charts import bar_table, one_pie_chart, two_pie_chart
# %pylab inline

# %%
whole_trips = pd.read_csv('%s/%s'%(trips_dir, 'whole-ap-tm-num-dur-fare.csv'))

# %%
Y09 = whole_trips[(whole_trips['yy'] == 9)]
Y10 = whole_trips[(whole_trips['yy'] == 10)]

# %%
Y09_gb, Y10_gb = Y09.groupby(['ap-trip-mode']), Y10.groupby(['ap-trip-mode'])
Y09_tm_num, Y10_tm_num = Y09_gb.sum()['num-tm'], Y10_gb.sum()['num-tm']

# %%
_data = [[ Y09_tm_num[DInAP_PInAP],  Y10_tm_num[DInAP_PInAP]],
        [ Y09_tm_num[DInAP_POutAP],  Y10_tm_num[DInAP_POutAP]]]
row_labels, col_labels = ['Pick up in AP', 'Pick up out AP'], ['Y2009', 'Y2010']

bar_table("", 'Number of trips', row_labels, col_labels, _data, 'Driver_decision_at_ap')
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2457: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if event.key in fullscreen_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2461: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if event.key in quit_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2466: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if event.key in home_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2470: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in back_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2473: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in forward_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2476: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in pan_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2480: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in zoom_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2484: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in save_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2493: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if event.key in grid_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2497: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in toggle_yscale_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2507: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif event.key in toggle_xscale_keys:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/backend_bases.py:2517: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif (event.key.isdigit() and event.key != '0') or event.key in all:

# %%
per_data1 = [_data[1][0] / (_data[0][0] + _data[1][0]), _data[0][0] / (_data[0][0] + _data[1][0])]
per_data2 = [_data[1][1] / (_data[0][1] + _data[1][1]), _data[0][1] / (_data[0][1] + _data[1][1])]

# %%
one_pie_chart('',per_data1, ['Pick up out AP', 'Pick up in AP'], 'Y2009_decision_at_ap')

# %%
one_pie_chart('',per_data2, ['Pick up out AP', 'Pick up in AP'], 'Y2010_decision_at_ap')

# %%
per_data1 = [_data[1][0] / (_data[0][0] + _data[1][0]), _data[0][0] / (_data[0][0] + _data[1][0])]
per_data2 = [_data[1][1] / (_data[0][1] + _data[1][1]), _data[0][1] / (_data[0][1] + _data[1][1])]
two_pie_chart(['Pick up out AP', 'Pick up in AP'], 
              "Y2009",per_data1,
              "Y2010",per_data2, 'percentile')
